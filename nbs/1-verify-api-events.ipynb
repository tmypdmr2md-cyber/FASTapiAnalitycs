# %%
# %pip install requests
# Out:
# Requirement already satisfied: requests in /Users/alexanderivanov/Desktop/Programming/FullStack /FastAPI/full-fastapi/venv/lib/python3.12/site-packages (2.33.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/alexanderivanov/Desktop/Programming/FullStack /FastAPI/full-fastapi/venv/lib/python3.12/site-packages (from requests) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/alexanderivanov/Desktop/Programming/FullStack /FastAPI/full-fastapi/venv/lib/python3.12/site-packages (from requests) (3.13)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/alexanderivanov/Desktop/Programming/FullStack /FastAPI/full-fastapi/venv/lib/python3.12/site-packages (from requests) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in /Users/alexanderivanov/Desktop/Programming/FullStack /FastAPI/full-fastapi/venv/lib/python3.12/site-packages (from requests) (2026.4.22)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests

path = "/api/events"
base_url = "http://localhost:8002"
endpoint = f"{base_url}{path}"
endpoint
# Out:
# 'http://localhost:8002/api/events'

# %%
response = requests.get(endpoint)

# %%
if response.ok:
    print("Status:", response.status_code)
    data = response.json()
    print(f"{data}\n{type(data)}\n{data.keys()}\n{data.get('items')}")
else:
    print("Failed:", response.status_code)
# Out:
# Status: 200
# {'items': '[1, 2, 3]'}
# <class 'dict'>
# dict_keys(['items'])
# [1, 2, 3]
